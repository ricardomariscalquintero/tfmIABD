# %% [markdown]
# ## 10. Entrenamiento de la Red Neuronal Convolucional (CNN)
#
# Aunque Spark MLlib ofrece algoritmos de aprendizaje automático integrados y distribuidos, **no está diseñado para trabajar con redes neuronales profundas como las CNN**. Las capacidades de MLlib se centran en modelos más clásicos como la regresión logística y lineal, árboles de decisión y bosques aleatorios, clustering (K-means), redes neuronales multicapa simples (perceptrones), ...)
#
# En este caso utilizamos **TensorFlowOnSpark (TFoS)**  para entrenar una red neuronal convolucional (CNN) en un clúster Spark. De este modo, se puede ejecutar código de TensorFlow de forma distribuida sobre Spark.
#
# Este enfoque es necesario porque entrenar modelos con grandes volúmenes de datos (como miles de posiciones FEN) puede superar la capacidad de memoria y procesamiento de una sola máquina. TFoS permite repartir tanto los datos como el entrenamiento entre múltiples nodos del clúster, manteniendo compatibilidad con APIs estándar de TensorFlow.
#
# La función `entrenar_cnn()` encapsula este proceso para reutilizarlo en los dos conjuntos de datos: partidas jugadas con blancas y con negras. Internamente:
# - Se define una arquitectura CNN simple para clasificar jugadas según la posición del tablero.
# - Se cargan y preparan los datos desde Parquet.
# - El entrenamiento se lanza distribuido con `TFCluster.run()`, donde cada nodo ejecuta una copia del modelo entrenando en paralelo.

# %%
def entrenar_cnn(data_path, model_path):
    import numpy as np
    import tensorflow as tf
    from pyspark.sql import SparkSession
    from tensorflowonspark import TFCluster

    from sklearn.model_selection import train_test_split

    spark = SparkSession.builder \
        .appName("TFoS-CNN") \
        .master("local[2]") \
        .config("spark.driver.memory", "2g") \
        .getOrCreate()
    sc = spark.sparkContext

    # Leer todos los datos EN EL DRIVER
    df = spark.read.parquet(data_path)
    features = df.select("features").rdd.map(lambda r: r[0]).collect()
    labels = df.select("label").rdd.map(lambda r: int(r[0])).collect()

    # Convertir en arrays numpy y particionar manualmente
    X = np.array(features).reshape(-1, 8, 8, 12)
    y = np.array(labels, dtype=np.int32)

    num_workers = 2  # Debe coincidir con num_executors
    partitions = [(X[i::num_workers], y[i::num_workers]) for i in range(num_workers)]

    # Argumentos que recibe cada worker (ya separados)
    args = {
        "data": partitions,
        "model_path": model_path
    }

    # Modelo CNN
    def model_fn(num_classes):
        model = tf.keras.Sequential([
            tf.keras.Input(shape=(8, 8, 12)),
            tf.keras.layers.Conv2D(64, (3, 3), activation='relu', padding='same'),
            tf.keras.layers.MaxPooling2D((2, 2)),
            tf.keras.layers.Flatten(),
            tf.keras.layers.Dense(128, activation='relu'),
            tf.keras.layers.Dense(num_classes, activation='softmax')
        ])
        model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
        return model

    # Función que corre en cada worker
    def main_fun(args, ctx):
        import tensorflow as tf
        from sklearn.model_selection import train_test_split
        import numpy as np

        X, y = args["data"][ctx.worker_num]  # Cada worker toma su partición

        num_classes = np.max(y) + 1
        X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1)

        model = model_fn(num_classes)
        history = model.fit(
            X_train, y_train,
            epochs=8,
            validation_data=(X_test, y_test),
            batch_size=32
        )


        if ctx.job_name == "chief":
            print(f"[CHIEF] Soy el chief (worker {ctx.worker_num})")
        
            # Guardar el modelo
            model.save(args["model_path"])
            print(f"[CHIEF] Modelo guardado en: {args['model_path']}")
        
            # Guardar el historial
            try:
                print(f"[CHIEF] Intentando guardar historial en: {args['model_path']}_history.pkl")
                import pickle
                with open(args["model_path"] + "_history.pkl", "wb") as f:
                    pickle.dump(history.history, f)
                print("[CHIEF] Historial guardado correctamente")
            except Exception as e:
                print(f"[CHIEF] Error al guardar historial: {e}")


    # Ejecutar el entrenamiento distribuido
    cluster = TFCluster.run(
        sc,
        main_fun,
        args,
        num_executors=num_workers,
        num_ps=1,
        input_mode=TFCluster.InputMode.TENSORFLOW,
        master_node="chief",
        log_dir="/tmp/tf_logs"
    )

# %%
## Pongo el destino en local para pruebas (no ocupa mucho)
entrenar_cnn(
    data_path="hdfs:///user/ajedrez/datos_cnn/blancas/fen_jugadas.parquet",
    model_path="/notebooks/datos_cnn/modelo_blancas"
)
# Out:
# 2025-07-08 20:38:15.574299: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-07-08 20:38:15.888365: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-07-08 20:38:15.889691: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-07-08 20:38:18.021904: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 25/07/08 20:38:27 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# 2025-07-08 20:38:55,744 INFO (MainThread-26) Reserving TFSparkNodes
# 2025-07-08 20:38:55,745 INFO (MainThread-26) cluster_template: {'ps': [0], 'chief': [1]}
# 2025-07-08 20:38:55,755 INFO (MainThread-26) Reservation server binding to port 0
# 2025-07-08 20:38:55,756 INFO (MainThread-26) listening for reservations at ('172.18.0.10', 43599)
# 2025-07-08 20:38:55,757 INFO (MainThread-26) Starting TensorFlow on executors
# 2025-07-08 20:38:55,763 INFO (MainThread-26) Waiting for TFSparkNodes to start
# 2025-07-08 20:38:55,764 INFO (MainThread-26) waiting for 2 reservations
# 2025-07-08 20:38:56,766 INFO (MainThread-26) waiting for 2 reservations
# 2025-07-08 20:38:57,769 INFO (MainThread-26) waiting for 2 reservations
# 2025-07-08 20:38:57.866633: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-07-08 20:38:57.872231: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-07-08 20:38:57.935428: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-07-08 20:38:57.935894: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-07-08 20:38:57.943620: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-07-08 20:38:57.944517: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-07-08 20:38:58,773 INFO (MainThread-26) waiting for 2 reservations+ 2) / 2]
# 2025-07-08 20:38:58.946159: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2025-07-08 20:38:58.947837: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2025-07-08 20:38:59,777 INFO (MainThread-26) waiting for 2 reservations
# 2025-07-08 20:39:00,780 INFO (MainThread-26) waiting for 2 reservations
# 2025-07-08 20:39:01,280 INFO (MainThread-209) connected to server at ('172.18.0.10', 43599)
# 2025-07-08 20:39:01,281 INFO (MainThread-209) TFSparkNode.reserve: {'executor_id': 1, 'host': '172.18.0.10', 'job_name': 'chief', 'task_index': 0, 'port': 33751, 'tb_pid': 0, 'tb_port': 0, 'addr': '/tmp/pymp-7y5hzaqn/listener-runv7z22', 'authkey': b'F+c<\x00\x95Lo\x81\xf4>\xc8\x82\xbb\xb7`'}
# 2025-07-08 20:39:01,446 INFO (MainThread-208) connected to server at ('172.18.0.10', 43599)
# 2025-07-08 20:39:01,446 INFO (MainThread-208) TFSparkNode.reserve: {'executor_id': 0, 'host': '172.18.0.10', 'job_name': 'ps', 'task_index': 0, 'port': 37849, 'tb_pid': 0, 'tb_port': 0, 'addr': ('172.18.0.10', 44483), 'authkey': b'#\x97\xbe\x1f\xceII\xc3\xa2\x9b\xe3\x9f\x00;\xbf]'}
# 2025-07-08 20:39:01,783 INFO (MainThread-26) all reservations completed
# 2025-07-08 20:39:01,784 INFO (MainThread-26) All TFSparkNodes started
# 2025-07-08 20:39:01,784 INFO (MainThread-26) {'executor_id': 1, 'host': '172.18.0.10', 'job_name': 'chief', 'task_index': 0, 'port': 33751, 'tb_pid': 0, 'tb_port': 0, 'addr': '/tmp/pymp-7y5hzaqn/listener-runv7z22', 'authkey': b'F+c<\x00\x95Lo\x81\xf4>\xc8\x82\xbb\xb7`'}
# 2025-07-08 20:39:01,785 INFO (MainThread-26) {'executor_id': 0, 'host': '172.18.0.10', 'job_name': 'ps', 'task_index': 0, 'port': 37849, 'tb_pid': 0, 'tb_port': 0, 'addr': ('172.18.0.10', 44483), 'authkey': b'#\x97\xbe\x1f\xceII\xc3\xa2\x9b\xe3\x9f\x00;\xbf]'}
# 2025-07-08 20:39:02,957 INFO (MainThread-208) node: {'executor_id': 0, 'host': '172.18.0.10', 'job_name': 'ps', 'task_index': 0, 'port': 37849, 'tb_pid': 0, 'tb_port': 0, 'addr': ('172.18.0.10', 44483), 'authkey': b'#\x97\xbe\x1f\xceII\xc3\xa2\x9b\xe3\x9f\x00;\xbf]'}
# 2025-07-08 20:39:02,957 INFO (MainThread-208) node: {'executor_id': 1, 'host': '172.18.0.10', 'job_name': 'chief', 'task_index': 0, 'port': 33751, 'tb_pid': 0, 'tb_port': 0, 'addr': '/tmp/pymp-7y5hzaqn/listener-runv7z22', 'authkey': b'F+c<\x00\x95Lo\x81\xf4>\xc8\x82\xbb\xb7`'}
# 2025-07-08 20:39:02,957 INFO (MainThread-208) export TF_CONFIG: {"cluster": {"ps": ["172.18.0.10:37849"], "chief": ["172.18.0.10:33751"]}, "task": {"type": "ps", "index": 0}, "environment": "cloud"}
# 2025-07-08 20:39:03,050 INFO (MainThread-208) Starting TensorFlow ps:0 as ps on cluster node 0 on background process
# 2025-07-08 20:39:03,959 INFO (MainThread-209) node: {'executor_id': 0, 'host': '172.18.0.10', 'job_name': 'ps', 'task_index': 0, 'port': 37849, 'tb_pid': 0, 'tb_port': 0, 'addr': ('172.18.0.10', 44483), 'authkey': b'#\x97\xbe\x1f\xceII\xc3\xa2\x9b\xe3\x9f\x00;\xbf]'}
# 2025-07-08 20:39:03,959 INFO (MainThread-209) node: {'executor_id': 1, 'host': '172.18.0.10', 'job_name': 'chief', 'task_index': 0, 'port': 33751, 'tb_pid': 0, 'tb_port': 0, 'addr': '/tmp/pymp-7y5hzaqn/listener-runv7z22', 'authkey': b'F+c<\x00\x95Lo\x81\xf4>\xc8\x82\xbb\xb7`'}
# 2025-07-08 20:39:03,959 INFO (MainThread-209) export TF_CONFIG: {"cluster": {"ps": ["172.18.0.10:37849"], "chief": ["172.18.0.10:33751"]}, "task": {"type": "chief", "index": 0}, "environment": "cloud"}
# 2025-07-08 20:39:04,020 INFO (MainThread-209) Starting TensorFlow chief:0 on cluster node 1 on foreground thread
# Epoch 1/8
# 2025-07-08 20:39:05.125293: W tensorflow/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 100611072 exceeds 10% of free system memory.
# Epoch 1/8
# 1024/1024 [==============================] - 28s 27ms/step - loss: 6.1198 - accuracy: 0.0385 - val_loss: 5.8083 - val_accuracy: 0.0516
# 1012/1024 [============================>.] - ETA: 0s - loss: 6.1167 - accuracy: 0.0370Epoch 2/8
# 1024/1024 [==============================] - 31s 29ms/step - loss: 6.1148 - accuracy: 0.0373 - val_loss: 5.7705 - val_accuracy: 0.0599
#  144/1024 [===>..........................] - ETA: 22s - loss: 5.7376 - accuracy: 0.0545Epoch 2/8
# 1024/1024 [==============================] - 25s 24ms/step - loss: 5.5960 - accuracy: 0.0727 - val_loss: 5.4682 - val_accuracy: 0.0819
# Epoch 3/8
# 1024/1024 [==============================] - 24s 23ms/step - loss: 5.5698 - accuracy: 0.0765 - val_loss: 5.4235 - val_accuracy: 0.0885
# Epoch 3/8
# 1024/1024 [==============================] - 18s 17ms/step - loss: 5.1347 - accuracy: 0.0967 - val_loss: 5.2415 - val_accuracy: 0.0986
#  934/1024 [==========================>...] - ETA: 1s - loss: 5.1134 - accuracy: 0.1009Epoch 4/8
# 1024/1024 [==============================] - 18s 17ms/step - loss: 5.1015 - accuracy: 0.1011 - val_loss: 5.1884 - val_accuracy: 0.1022
# Epoch 4/8
# 1024/1024 [==============================] - 20s 19ms/step - loss: 4.7026 - accuracy: 0.1175 - val_loss: 5.1003 - val_accuracy: 0.1099
# Epoch 5/8
# 1024/1024 [==============================] - 19s 18ms/step - loss: 4.6408 - accuracy: 0.1227 - val_loss: 5.0333 - val_accuracy: 0.1124
# Epoch 5/8
# 1024/1024 [==============================] - 13s 13ms/step - loss: 4.2904 - accuracy: 0.1410 - val_loss: 5.0604 - val_accuracy: 0.1198
# Epoch 6/8
# 1024/1024 [==============================] - 13s 13ms/step - loss: 4.1978 - accuracy: 0.1485 - val_loss: 4.9934 - val_accuracy: 0.1212
# Epoch 6/8
# 1024/1024 [==============================] - 14s 13ms/step - loss: 3.8994 - accuracy: 0.1737 - val_loss: 5.0923 - val_accuracy: 0.1236
# Epoch 7/8
# 1024/1024 [==============================] - 14s 14ms/step - loss: 3.7821 - accuracy: 0.1851 - val_loss: 5.0583 - val_accuracy: 0.1245
# Epoch 7/8
# 1024/1024 [==============================] - 13s 12ms/step - loss: 3.5516 - accuracy: 0.2057 - val_loss: 5.1831 - val_accuracy: 0.1264
# Epoch 8/8
# 1024/1024 [==============================] - 13s 12ms/step - loss: 3.4192 - accuracy: 0.2227 - val_loss: 5.1336 - val_accuracy: 0.1325
# Epoch 8/8
# 1024/1024 [==============================] - 13s 13ms/step - loss: 3.2424 - accuracy: 0.2464 - val_loss: 5.3506 - val_accuracy: 0.1280
# 1024/1024 [==============================] - 12s 12ms/step - loss: 3.1069 - accuracy: 0.2657 - val_loss: 5.2812 - val_accuracy: 0.1407
# [CHIEF] Soy el chief (worker 1)
# INFO:tensorflow:Assets written to: /notebooks/datos_cnn/modelo_blancas/assets
# 2025-07-08 20:41:29,978 INFO (MainThread-209) Assets written to: /notebooks/datos_cnn/modelo_blancas/assets
# [CHIEF] Modelo guardado en: /notebooks/datos_cnn/modelo_blancas
# [CHIEF] Intentando guardar historial en: /notebooks/datos_cnn/modelo_blancas_history.pkl
# [CHIEF] Historial guardado correctamente
# 2025-07-08 20:41:29,999 INFO (MainThread-209) Finished TensorFlow chief:0 on cluster node 1
# [Stage 3:=============================>                             (1 + 1) / 2]

# %%
## IMPORTANTE: REINICIAR EL KERNEL
## Ejecutar la celda de la función "entrenar_cnn" y luego la siguiente, el modelo para negras

# %%
# Modelo para negras
entrenar_cnn(
    data_path="hdfs:///user/ajedrez/datos_cnn/negras/fen_jugadas.parquet",
    model_path="/notebooks/datos_cnn/modelo_negras"
)
# Out:
# 2025-06-26 15:23:29.416882: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-06-26 15:23:29.466380: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-06-26 15:23:29.467057: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-06-26 15:23:30.443249: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 25/06/26 15:23:34 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# 2025-06-26 15:23:54,753 INFO (MainThread-765) Reserving TFSparkNodes
# 2025-06-26 15:23:54,755 INFO (MainThread-765) cluster_template: {'ps': [0], 'chief': [1]}
# 2025-06-26 15:23:54,763 INFO (MainThread-765) Reservation server binding to port 0
# 2025-06-26 15:23:54,783 INFO (MainThread-765) listening for reservations at ('172.18.0.10', 46265)
# 2025-06-26 15:23:54,784 INFO (MainThread-765) Starting TensorFlow on executors
# 2025-06-26 15:23:54,796 INFO (MainThread-765) Waiting for TFSparkNodes to start
# 2025-06-26 15:23:54,797 INFO (MainThread-765) waiting for 2 reservations
# 2025-06-26 15:23:55,803 INFO (MainThread-765) waiting for 2 reservations
# 2025-06-26 15:23:56.804505: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-06-26 15:23:56,805 INFO (MainThread-765) waiting for 2 reservations
# 2025-06-26 15:23:56.837928: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-06-26 15:23:56.862934: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-06-26 15:23:56.863438: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-06-26 15:23:56.905630: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-06-26 15:23:56.906132: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-06-26 15:23:57.720464: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2025-06-26 15:23:57.751291: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2025-06-26 15:23:57,807 INFO (MainThread-765) waiting for 2 reservations
# 2025-06-26 15:23:58,809 INFO (MainThread-765) waiting for 2 reservations
# 2025-06-26 15:23:59,718 INFO (MainThread-942) connected to server at ('172.18.0.10', 46265)
# 2025-06-26 15:23:59,719 INFO (MainThread-942) TFSparkNode.reserve: {'executor_id': 1, 'host': '172.18.0.10', 'job_name': 'chief', 'task_index': 0, 'port': 44223, 'tb_pid': 0, 'tb_port': 0, 'addr': '/tmp/pymp-d0wkwp25/listener-1o5sis43', 'authkey': b'\x99\xc8e\xd0O\xf1H\xe0\x83Q\xa7\xd5$-\xe2\xaa'}
# 2025-06-26 15:23:59,811 INFO (MainThread-765) waiting for 1 reservations
# 2025-06-26 15:23:59,908 INFO (MainThread-944) connected to server at ('172.18.0.10', 46265)
# 2025-06-26 15:23:59,909 INFO (MainThread-944) TFSparkNode.reserve: {'executor_id': 0, 'host': '172.18.0.10', 'job_name': 'ps', 'task_index': 0, 'port': 45741, 'tb_pid': 0, 'tb_port': 0, 'addr': ('172.18.0.10', 44645), 'authkey': b'\xa7\x81u\x16@VMO\x90;\xcc\xe3\xf5\x8e*\xe4'}
# 2025-06-26 15:24:00,813 INFO (MainThread-765) all reservations completed
# 2025-06-26 15:24:00,814 INFO (MainThread-765) All TFSparkNodes started
# 2025-06-26 15:24:00,815 INFO (MainThread-765) {'executor_id': 1, 'host': '172.18.0.10', 'job_name': 'chief', 'task_index': 0, 'port': 44223, 'tb_pid': 0, 'tb_port': 0, 'addr': '/tmp/pymp-d0wkwp25/listener-1o5sis43', 'authkey': b'\x99\xc8e\xd0O\xf1H\xe0\x83Q\xa7\xd5$-\xe2\xaa'}
# 2025-06-26 15:24:00,816 INFO (MainThread-765) {'executor_id': 0, 'host': '172.18.0.10', 'job_name': 'ps', 'task_index': 0, 'port': 45741, 'tb_pid': 0, 'tb_port': 0, 'addr': ('172.18.0.10', 44645), 'authkey': b'\xa7\x81u\x16@VMO\x90;\xcc\xe3\xf5\x8e*\xe4'}
# 2025-06-26 15:24:01,951 INFO (MainThread-944) node: {'executor_id': 0, 'host': '172.18.0.10', 'job_name': 'ps', 'task_index': 0, 'port': 45741, 'tb_pid': 0, 'tb_port': 0, 'addr': ('172.18.0.10', 44645), 'authkey': b'\xa7\x81u\x16@VMO\x90;\xcc\xe3\xf5\x8e*\xe4'}
# 2025-06-26 15:24:01,952 INFO (MainThread-944) node: {'executor_id': 1, 'host': '172.18.0.10', 'job_name': 'chief', 'task_index': 0, 'port': 44223, 'tb_pid': 0, 'tb_port': 0, 'addr': '/tmp/pymp-d0wkwp25/listener-1o5sis43', 'authkey': b'\x99\xc8e\xd0O\xf1H\xe0\x83Q\xa7\xd5$-\xe2\xaa'}
# 2025-06-26 15:24:01,952 INFO (MainThread-944) export TF_CONFIG: {"cluster": {"ps": ["172.18.0.10:45741"], "chief": ["172.18.0.10:44223"]}, "task": {"type": "ps", "index": 0}, "environment": "cloud"}
# 2025-06-26 15:24:01,957 INFO (MainThread-942) node: {'executor_id': 0, 'host': '172.18.0.10', 'job_name': 'ps', 'task_index': 0, 'port': 45741, 'tb_pid': 0, 'tb_port': 0, 'addr': ('172.18.0.10', 44645), 'authkey': b'\xa7\x81u\x16@VMO\x90;\xcc\xe3\xf5\x8e*\xe4'}
# 2025-06-26 15:24:01,957 INFO (MainThread-942) node: {'executor_id': 1, 'host': '172.18.0.10', 'job_name': 'chief', 'task_index': 0, 'port': 44223, 'tb_pid': 0, 'tb_port': 0, 'addr': '/tmp/pymp-d0wkwp25/listener-1o5sis43', 'authkey': b'\x99\xc8e\xd0O\xf1H\xe0\x83Q\xa7\xd5$-\xe2\xaa'}
# 2025-06-26 15:24:01,958 INFO (MainThread-942) export TF_CONFIG: {"cluster": {"ps": ["172.18.0.10:45741"], "chief": ["172.18.0.10:44223"]}, "task": {"type": "chief", "index": 0}, "environment": "cloud"}
# 2025-06-26 15:24:02,015 INFO (MainThread-944) Starting TensorFlow ps:0 as ps on cluster node 0 on background process
# 2025-06-26 15:24:02,017 INFO (MainThread-942) Starting TensorFlow chief:0 on cluster node 1 on foreground thread
# Epoch 1/5
# Epoch 1/5
# 1029/1029 [==============================] - 12s 11ms/step - loss: 6.1774 - accuracy: 0.0319 - val_loss: 5.8862 - val_accuracy: 0.0522
# Epoch 2/5
# 1029/1029 [==============================] - 12s 11ms/step - loss: 6.1657 - accuracy: 0.0340 - val_loss: 5.8726 - val_accuracy: 0.0563
# Epoch 2/5
# 1029/1029 [==============================] - 9s 9ms/step - loss: 5.5965 - accuracy: 0.0717 - val_loss: 5.5053 - val_accuracy: 0.0842
# Epoch 3/5
# 1029/1029 [==============================] - 9s 9ms/step - loss: 5.5811 - accuracy: 0.0717 - val_loss: 5.5348 - val_accuracy: 0.0850
# Epoch 3/5
# 1029/1029 [==============================] - 9s 9ms/step - loss: 5.0459 - accuracy: 0.1013 - val_loss: 5.2462 - val_accuracy: 0.1009
# Epoch 4/5
# 1029/1029 [==============================] - 9s 9ms/step - loss: 5.0353 - accuracy: 0.0984 - val_loss: 5.2223 - val_accuracy: 0.0973
# Epoch 4/5
# 1029/1029 [==============================] - 11s 11ms/step - loss: 4.5219 - accuracy: 0.1305 - val_loss: 5.1267 - val_accuracy: 0.1088
# Epoch 5/5
# 1029/1029 [==============================] - 11s 11ms/step - loss: 4.4883 - accuracy: 0.1297 - val_loss: 5.0535 - val_accuracy: 0.1099
# Epoch 5/5
# 1029/1029 [==============================] - 10s 10ms/step - loss: 3.9970 - accuracy: 0.1622 - val_loss: 4.9879 - val_accuracy: 0.1249
# 1029/1029 [==============================] - 10s 10ms/step - loss: 4.0396 - accuracy: 0.1647 - val_loss: 5.1159 - val_accuracy: 0.1156
# INFO:tensorflow:Assets written to: /notebooks/datos_cnn/modelo_negras/assets
# 2025-06-26 15:24:55,960 INFO (MainThread-942) Assets written to: /notebooks/datos_cnn/modelo_negras/assets
# Modelo guardado en: /notebooks/datos_cnn/modelo_negras
# 2025-06-26 15:24:55,976 INFO (MainThread-942) Finished TensorFlow chief:0 on cluster node 1
# [Stage 3:=============================>                             (1 + 1) / 2]

# %%
#!ls -l /notebooks/datos_cnn/modelo_blancas/
#!ls -l /notebooks/datos_cnn/modelo_negras/
# Out:
# IOStream.flush timed out
# total 128
# drwxr-xr-x 2 1000 1000   4096 May 11 20:45 assets
# -rw-r--r-- 1 root root     55 Jun 26 15:20 fingerprint.pb
# -rw-r--r-- 1 1000 1000  11668 Jun 26 15:20 keras_metadata.pb
# -rw-r--r-- 1 root root 102885 Jun 26 15:20 saved_model.pb
# drwxr-xr-x 2 1000 1000   4096 Jun 26 15:20 variables
# IOStream.flush timed out
# total 128
# drwxr-xr-x 2 1000 1000   4096 May 12 07:36 assets
# -rw-r--r-- 1 root root     57 Jun 26 15:24 fingerprint.pb
# -rw-r--r-- 1 1000 1000  11668 Jun 26 15:24 keras_metadata.pb
# -rw-r--r-- 1 root root 102885 Jun 26 15:24 saved_model.pb
# drwxr-xr-x 2 1000 1000   4096 Jun 26 15:24 variables
# [Stage 3:=============================>                             (1 + 1) / 2]

# %% [markdown]
# ## 11. Evaluación del entrenamiento. Precisión Top-k (blancas)

# %%
import pickle
import matplotlib.pyplot as plt
from tensorflow.keras.models import load_model
import numpy as np

# Rutas al modelo y al historial (ajusta si es necesario)
model_path = "/notebooks/datos_cnn/modelo_blancas"
history_path = model_path + "_history.pkl"

# Cargar historial
with open(history_path, "rb") as f:
    history = pickle.load(f)

# Mostrar claves disponibles (opcional)
print("Métricas disponibles en el historial:", list(history.keys()))

# Crear vector de épocas comenzando en 1
epochs = range(1, len(history["accuracy"]) + 1)

# Graficar precisión
plt.figure(figsize=(8, 5))
plt.plot(epochs, history["accuracy"], label="Entrenamiento")
plt.plot(epochs, history["val_accuracy"], label="Validación")
plt.title("Precisión por época")
plt.xlabel("Época")
plt.ylabel("Precisión")
plt.legend()
plt.grid(True)
plt.savefig("precision.png")   
plt.show()

# Graficar pérdida
plt.figure(figsize=(8, 5))
plt.plot(epochs, history["loss"], label="Entrenamiento")
plt.plot(epochs, history["val_loss"], label="Validación")
plt.title("Pérdida por época")
plt.xlabel("Época")
plt.ylabel("Pérdida")
plt.legend()
plt.grid(True)
plt.savefig("perdida.png") 
plt.savefig(model_path + "_grafica_perdida.png") 
plt.show()
# Out:
# 2025-07-08 20:41:40,821 INFO (MainThread-26) generated new fontManager
# Métricas disponibles en el historial: ['loss', 'accuracy', 'val_loss', 'val_accuracy']

# %%
import numpy as np
import pickle
from tensorflow.keras.models import load_model
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from pyspark.sql import SparkSession

# --- Rutas ---
model_path = "/notebooks/datos_cnn/modelo_blancas"
history_path = model_path + "_history.pkl"
data_path = "hdfs:///user/ajedrez/datos_cnn/blancas/fen_jugadas.parquet"

# --- Cargar modelo y historial ---
model = load_model(model_path)

with open(history_path, "rb") as f:
    history = pickle.load(f)

# --- Cargar datos desde HDFS con Spark ---
spark = SparkSession.builder \
    .appName("CargarDatosTest") \
    .master("local[2]") \
    .config("spark.driver.memory", "2g") \
    .getOrCreate()

df = spark.read.parquet(data_path)

# Extraer features y labels al driver
features = df.select("features").rdd.map(lambda r: r[0]).collect()
labels = df.select("label").rdd.map(lambda r: int(r[0])).collect()

# Convertir a NumPy
X = np.array(features).reshape(-1, 8, 8, 12)
y = np.array(labels, dtype=np.int32)

# Separar conjunto de test
_, X_test, _, y_test = train_test_split(X, y, test_size=0.1, random_state=42)

# --- Predicciones ---
y_pred = model.predict(X_test)
num_classes = y_pred.shape[1]

# --- Función top-k accuracy ---
def top_k_accuracy(y_true, y_pred, k=5):
    top_k_preds = np.argsort(y_pred, axis=1)[:, -k:]
    return np.mean([y_true[i] in top_k_preds[i] for i in range(len(y_true))])

# --- Imprimir resultados top-k ---
for k in [3, 5, 7]:
    acc = top_k_accuracy(y_test, y_pred, k=k)
    print(f"Top-{k} accuracy: {acc*100:.2f}%")

# --- Visualización ---
accuracies = [top_k_accuracy(y_test, y_pred, k=k)*100 for k in [3, 5, 7]]
plt.bar(["Top-3", "Top-5", "Top-7"], accuracies)
plt.title("Precisión Top-K")
plt.ylabel("Precisión (%)")
plt.ylim(0, 100)
plt.grid(True, axis='y')
plt.savefig("topk_accuracy.png")
plt.show()
# Out:
# 25/07/08 20:41:47 WARN SparkSession: Using an existing Spark session; only runtime SQL configurations will take effect.
# [Stage 3:=============================>                             (1 + 1) / 2]
# 228/228 [==============================] - 1s 4ms/step
# Top-3 accuracy: 38.07%

# %% [markdown]
# ## 12. Juega contra Nakamura
#
# Este entorno de juego implementa una partida de ajedrez entre un jugador humano y un jugador artificial llamado "Nakamura". El bot ha sido entrenado para jugar tanto con blancas como con negras. El objetivo del bot no es solo ganar la partida, sino hacerlo **imitando su estilo humano**.
#
# El bot toma sus decisiones combinando la potencia táctica de **Stockfish** con una **red neuronal convolucional entrenada** sobre partidas reales. La lógica interna sigue este flujo:
#
# 1. **Evaluación de la posición (Stockfish).** A partir de la posición actual en formato FEN, Stockfish (parámetros similares a los de nuestro jugador real `ELO = 2800` y `habilidad = 20`) genera una lista de las mejores jugadas disponibles `(top_n=10)`, cada una con su evaluación (en centipawns o con amenaza de mate).
#
# 2. **Intervención de la red neuronal.** La posición del tablero se transforma en un tensor de dimensiones `(8, 8, 12)`, que representa cada pieza en cada casilla como un plano de activación. El modelo evalúa todas las posibles jugadas y asigna una puntuación aprendida durante el entrenamiento. De entre las jugadas razonables (filtradas por Stockfish), se elige aquella con **mayor puntuación de la red neuronal**.
#
# 3. **Ejecución del movimiento:**
#    - Si hay una única jugada claramente superior, se ejecuta directamente. Por ejemplo, comer una ficha importante por despiste del rival.
#    - En caso de varias buenas opciones, se prioriza la que la IA considera más representativa del "estilo Nakamura".
#    - La opción elegida en cada caso se muestra durante la partida junto con su notación algebraica.
#
# La red neuronal no reemplaza a Stockfish, sino que **lo complementa**. Mientras el motor garantiza que las jugadas sean sólidas, la IA aporta personalidad: **elige entre varias jugadas buenas aquella que se parece más a un humano**. Esto hace que el bot no solo busque precisión, sino que lo haga con una estrategia y fluidez más natural, más impredecible, más creativa.

# %% [markdown]
# <span style="color:blue">
#
# Ahora hay que:
# - Bajar los contenedores: `docker compose down`
# - En el host de Linux, fuera de los contenedores: `xhost +local:root` Otra opción es acordarse de ejecutarlo antes de levantar los contenedores siempre.
# - Subir los contenedores: `docker compose up -d`
# - Ejecutar las siguientes celdas.
# </span>

# %%
# !pip install pygame
# Out:
# Collecting pygame
#   Downloading pygame-2.6.1-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (14.0 MB)
#      |████████████████████████████████| 14.0 MB 1.1 MB/s eta 0:00:01
# Installing collected packages: pygame
# Successfully installed pygame-2.6.1

# %%
# Instalar el wrapper de Python para Stockfish pero también se necesita el binario ejecutable en el sistema
# !pip install stockfish
# Out:
# Collecting stockfish
#   Downloading stockfish-3.28.0-py3-none-any.whl (13 kB)
# Installing collected packages: stockfish
# Successfully installed stockfish-3.28.0

# %%
# INSTALACION DEL EJECUTABLE ( solo una vez, luego se queda en la carpeta /notebooks/motor_ejecutable )
# Desde el bash de spark-client:

#cd /notebooks
#rm -rf Stockfish
#git clone --branch sf_15 https://github.com/official-stockfish/Stockfish.git
#cd Stockfish/src
#make build ARCH=x86-64
#mkdir -p /notebooks/motor_ejecutable
#cp stockfish /notebooks/motor_ejecutable/stockfish
#chmod +x /notebooks/motor_ejecutable/stockfish
# Out:
# [Stage 0:=============================>                             (1 + 1) / 2]

# %%
# Instalar comunicación X11 
# !apt update && apt install -y x11-utils x11-xserver-utils x11-apps
# Out:
# Hit:1 http://deb.debian.org/debian bullseye InRelease
# Get:2 http://deb.debian.org/debian-security bullseye-security InRelease [27.2 kB]
# Get:3 http://deb.debian.org/debian bullseye-updates InRelease [44.0 kB]
# Get:4 http://deb.debian.org/debian-security bullseye-security/main amd64 Packages [383 kB]
# Fetched 454 kB in 1s (567 kB/s)
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# 71 packages can be upgraded. Run 'apt list --upgradable' to see them.
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following additional packages will be installed:
#   bsdextrautils groff-base libdrm-amdgpu1 libdrm-common libdrm-intel1
#   libdrm-nouveau2 libdrm-radeon1 libdrm2 libelf1 libfontenc1 libgl1
#   libgl1-mesa-dri libglapi-mesa libglvnd0 libglx-mesa0 libglx0 libice6
#   libllvm11 libpciaccess0 libpipeline1 libsensors-config libsensors5 libsm6
#   libuchardet0 libvulkan1 libwayland-client0 libx11-xcb1 libxaw7 libxcb-dri2-0
#   libxcb-dri3-0 libxcb-glx0 libxcb-present0 libxcb-randr0 libxcb-shape0
#   libxcb-shm0 libxcb-sync1 libxcb-xfixes0 libxcomposite1 libxcursor1
#   libxdamage1 libxext6 libxfixes3 libxft2 libxi6 libxinerama1 libxkbfile1
#   libxmu6 libxmuu1 libxrandr2 libxrender1 libxshmfence1 libxt6 libxtst6 libxv1
#   libxxf86dga1 libxxf86vm1 libz3-4 man-db mesa-vulkan-drivers x11-common
#   xbitmaps
# Suggested packages:
#   groff pciutils lm-sensors apparmor less www-browser mesa-utils nickle
#   cairo-5c xorg-docs-core
# The following NEW packages will be installed:
#   bsdextrautils groff-base libdrm-amdgpu1 libdrm-common libdrm-intel1
#   libdrm-nouveau2 libdrm-radeon1 libdrm2 libelf1 libfontenc1 libgl1
#   libgl1-mesa-dri libglapi-mesa libglvnd0 libglx-mesa0 libglx0 libice6
#   libllvm11 libpciaccess0 libpipeline1 libsensors-config libsensors5 libsm6
#   libuchardet0 libvulkan1 libwayland-client0 libx11-xcb1 libxaw7 libxcb-dri2-0
#   libxcb-dri3-0 libxcb-glx0 libxcb-present0 libxcb-randr0 libxcb-shape0
#   libxcb-shm0 libxcb-sync1 libxcb-xfixes0 libxcomposite1 libxcursor1
#   libxdamage1 libxext6 libxfixes3 libxft2 libxi6 libxinerama1 libxkbfile1
#   libxmu6 libxmuu1 libxrandr2 libxrender1 libxshmfence1 libxt6 libxtst6 libxv1
#   libxxf86dga1 libxxf86vm1 libz3-4 man-db mesa-vulkan-drivers x11-apps
#   x11-common x11-utils x11-xserver-utils xbitmaps
# 0 upgraded, 64 newly installed, 0 to remove and 71 not upgraded.
# Need to get 45.8 MB of archives.
# After this operation, 183 MB of additional disk space will be used.
# Get:1 http://deb.debian.org/debian bullseye/main amd64 bsdextrautils amd64 2.36.1-8+deb11u2 [146 kB]
# Get:2 http://deb.debian.org/debian bullseye/main amd64 libuchardet0 amd64 0.0.7-1 [67.8 kB]
# Get:3 http://deb.debian.org/debian bullseye/main amd64 groff-base amd64 1.22.4-6 [936 kB]
# Get:4 http://deb.debian.org/debian bullseye/main amd64 libpipeline1 amd64 1.5.3-1 [34.3 kB]
# Get:5 http://deb.debian.org/debian bullseye/main amd64 man-db amd64 2.9.4-2 [1354 kB]
# Get:6 http://deb.debian.org/debian bullseye/main amd64 libdrm-common all 2.4.104-1 [14.9 kB]
# Get:7 http://deb.debian.org/debian bullseye/main amd64 libdrm2 amd64 2.4.104-1 [41.5 kB]
# Get:8 http://deb.debian.org/debian bullseye/main amd64 libdrm-amdgpu1 amd64 2.4.104-1 [28.5 kB]
# Get:9 http://deb.debian.org/debian bullseye/main amd64 libpciaccess0 amd64 0.16-1 [53.6 kB]
# Get:10 http://deb.debian.org/debian bullseye/main amd64 libdrm-intel1 amd64 2.4.104-1 [71.8 kB]
# Get:11 http://deb.debian.org/debian bullseye/main amd64 libdrm-nouveau2 amd64 2.4.104-1 [26.8 kB]
# Get:12 http://deb.debian.org/debian bullseye/main amd64 libdrm-radeon1 amd64 2.4.104-1 [30.2 kB]
# Get:13 http://deb.debian.org/debian bullseye/main amd64 libelf1 amd64 0.183-1 [165 kB]
# Get:14 http://deb.debian.org/debian bullseye/main amd64 libfontenc1 amd64 1:1.1.4-1 [24.3 kB]
# Get:15 http://deb.debian.org/debian bullseye/main amd64 libglapi-mesa amd64 20.3.5-1 [71.7 kB]
# Get:16 http://deb.debian.org/debian bullseye/main amd64 libz3-4 amd64 4.8.10-1 [6949 kB]
# Get:17 http://deb.debian.org/debian bullseye/main amd64 libllvm11 amd64 1:11.0.1-2 [17.9 MB]
# Get:18 http://deb.debian.org/debian bullseye/main amd64 libsensors-config all 1:3.6.0-7 [32.3 kB]
# Get:19 http://deb.debian.org/debian bullseye/main amd64 libsensors5 amd64 1:3.6.0-7 [52.3 kB]
# Get:20 http://deb.debian.org/debian bullseye/main amd64 libvulkan1 amd64 1.2.162.0-1 [103 kB]
# Get:21 http://deb.debian.org/debian bullseye/main amd64 libgl1-mesa-dri amd64 20.3.5-1 [9633 kB]
# Get:22 http://deb.debian.org/debian bullseye/main amd64 libglvnd0 amd64 1.3.2-1 [53.6 kB]
# Get:23 http://deb.debian.org/debian bullseye/main amd64 libx11-xcb1 amd64 2:1.7.2-1+deb11u2 [204 kB]
# Get:24 http://deb.debian.org/debian bullseye/main amd64 libxcb-dri2-0 amd64 1.14-3 [103 kB]
# Get:25 http://deb.debian.org/debian bullseye/main amd64 libxcb-dri3-0 amd64 1.14-3 [102 kB]
# Get:26 http://deb.debian.org/debian bullseye/main amd64 libxcb-glx0 amd64 1.14-3 [118 kB]
# Get:27 http://deb.debian.org/debian bullseye/main amd64 libxcb-present0 amd64 1.14-3 [101 kB]
# Get:28 http://deb.debian.org/debian bullseye/main amd64 libxcb-shm0 amd64 1.14-3 [101 kB]
# Get:29 http://deb.debian.org/debian bullseye/main amd64 libxcb-sync1 amd64 1.14-3 [105 kB]
# Get:30 http://deb.debian.org/debian bullseye/main amd64 libxcb-xfixes0 amd64 1.14-3 [105 kB]
# Get:31 http://deb.debian.org/debian bullseye/main amd64 libxdamage1 amd64 1:1.1.5-2 [15.7 kB]
# Get:32 http://deb.debian.org/debian bullseye/main amd64 libxext6 amd64 2:1.3.3-1.1 [52.7 kB]
# Get:33 http://deb.debian.org/debian bullseye/main amd64 libxfixes3 amd64 1:5.0.3-2 [22.1 kB]
# Get:34 http://deb.debian.org/debian bullseye/main amd64 libxshmfence1 amd64 1.3-1 [8820 B]
# Get:35 http://deb.debian.org/debian bullseye/main amd64 libxxf86vm1 amd64 1:1.1.4-1+b2 [20.8 kB]
# Get:36 http://deb.debian.org/debian bullseye/main amd64 libglx-mesa0 amd64 20.3.5-1 [186 kB]
# Get:37 http://deb.debian.org/debian bullseye/main amd64 x11-common all 1:7.7+22 [252 kB]
# Get:38 http://deb.debian.org/debian bullseye/main amd64 libice6 amd64 2:1.0.10-1 [58.5 kB]
# Get:39 http://deb.debian.org/debian bullseye/main amd64 libsm6 amd64 2:1.2.3-1 [35.1 kB]
# Get:40 http://deb.debian.org/debian bullseye/main amd64 libwayland-client0 amd64 1.18.0-2~exp1.1 [26.9 kB]
# Get:41 http://deb.debian.org/debian bullseye/main amd64 libxt6 amd64 1:1.2.0-1 [189 kB]
# Get:42 http://deb.debian.org/debian bullseye/main amd64 libxmu6 amd64 2:1.1.2-2+b3 [60.8 kB]
# Get:43 http://deb.debian.org/debian bullseye/main amd64 libxaw7 amd64 2:1.0.13-1.1 [202 kB]
# Get:44 http://deb.debian.org/debian bullseye/main amd64 libxcb-randr0 amd64 1.14-3 [113 kB]
# Get:45 http://deb.debian.org/debian bullseye/main amd64 libxcb-shape0 amd64 1.14-3 [102 kB]
# Get:46 http://deb.debian.org/debian bullseye/main amd64 libxcomposite1 amd64 1:0.4.5-1 [16.6 kB]
# Get:47 http://deb.debian.org/debian bullseye/main amd64 libxrender1 amd64 1:0.9.10-1 [33.0 kB]
# Get:48 http://deb.debian.org/debian bullseye/main amd64 libxcursor1 amd64 1:1.2.0-2 [37.3 kB]
# Get:49 http://deb.debian.org/debian bullseye/main amd64 libxft2 amd64 2.3.2-2 [57.2 kB]
# Get:50 http://deb.debian.org/debian bullseye/main amd64 libxi6 amd64 2:1.7.10-1 [83.4 kB]
# Get:51 http://deb.debian.org/debian bullseye/main amd64 libxinerama1 amd64 2:1.1.4-2 [17.7 kB]
# Get:52 http://deb.debian.org/debian bullseye/main amd64 libxkbfile1 amd64 1:1.1.0-1 [75.2 kB]
# Get:53 http://deb.debian.org/debian bullseye/main amd64 libxmuu1 amd64 2:1.1.2-2+b3 [23.9 kB]
# Get:54 http://deb.debian.org/debian bullseye/main amd64 libxrandr2 amd64 2:1.5.1-1 [37.5 kB]
# Get:55 http://deb.debian.org/debian bullseye/main amd64 libxtst6 amd64 2:1.2.3-1 [27.8 kB]
# Get:56 http://deb.debian.org/debian bullseye/main amd64 libxv1 amd64 2:1.0.11-1 [24.6 kB]
# Get:57 http://deb.debian.org/debian bullseye/main amd64 libxxf86dga1 amd64 2:1.1.4-1+b3 [22.1 kB]
# Get:58 http://deb.debian.org/debian bullseye/main amd64 mesa-vulkan-drivers amd64 20.3.5-1 [4086 kB]
# Get:59 http://deb.debian.org/debian bullseye/main amd64 x11-apps amd64 7.7+8 [662 kB]
# Get:60 http://deb.debian.org/debian bullseye/main amd64 libglx0 amd64 1.3.2-1 [35.7 kB]m
# Get:61 http://deb.debian.org/debian bullseye/main amd64 libgl1 amd64 1.3.2-1 [89.5 kB]3m
# Get:62 http://deb.debian.org/debian bullseye/main amd64 x11-utils amd64 7.7+5 [202 kB]
# Get:63 http://deb.debian.org/debian bullseye/main amd64 x11-xserver-utils amd64 7.7+8 [168 kB]
# Get:64 http://deb.debian.org/debian bullseye/main amd64 xbitmaps all 1.1.1-2.1 [25.8 kB]
# Fetched 45.8 MB in 6s (7373 kB/s)
# debconf: delaying package configuration, since apt-utils is not installed
#
# 78Selecting previously unselected package bsdextrautils.
# (Reading database ... 20268 files and directories currently installed.)
# Preparing to unpack .../00-bsdextrautils_2.36.1-8+deb11u2_amd64.deb ...
# 7Progress: [  0%] [..........................................................] 8Unpacking bsdextrautils (2.36.1-8+deb11u2) ...
# Selecting previously unselected package libuchardet0:amd64.
# Preparing to unpack .../01-libuchardet0_0.0.7-1_amd64.deb ...
# 7Progress: [  1%] [..........................................................] 8Unpacking libuchardet0:amd64 (0.0.7-1) ...
# Selecting previously unselected package groff-base.
# Preparing to unpack .../02-groff-base_1.22.4-6_amd64.deb ...
# Unpacking groff-base (1.22.4-6) ...
# 7Progress: [  2%] [#.........................................................] 8Selecting previously unselected package libpipeline1:amd64.
# Preparing to unpack .../03-libpipeline1_1.5.3-1_amd64.deb ...
# Unpacking libpipeline1:amd64 (1.5.3-1) ...
# 7Progress: [  3%] [#.........................................................] 8Selecting previously unselected package man-db.
# Preparing to unpack .../04-man-db_2.9.4-2_amd64.deb ...
# Unpacking man-db (2.9.4-2) ...
# Selecting previously unselected package libdrm-common.
# Preparing to unpack .../05-libdrm-common_2.4.104-1_all.deb ...
# 7Progress: [  4%] [##........................................................] 8Unpacking libdrm-common (2.4.104-1) ...
# Selecting previously unselected package libdrm2:amd64.
# Preparing to unpack .../06-libdrm2_2.4.104-1_amd64.deb ...
# 7Progress: [  5%] [##........................................................] 8Unpacking libdrm2:amd64 (2.4.104-1) ...
# Selecting previously unselected package libdrm-amdgpu1:amd64.
# Preparing to unpack .../07-libdrm-amdgpu1_2.4.104-1_amd64.deb ...
# Unpacking libdrm-amdgpu1:amd64 (2.4.104-1) ...
# 7Progress: [  6%] [###.......................................................] 8Selecting previously unselected package libpciaccess0:amd64.
# Preparing to unpack .../08-libpciaccess0_0.16-1_amd64.deb ...
# Unpacking libpciaccess0:amd64 (0.16-1) ...
# 7Progress: [  7%] [####......................................................] 8Selecting previously unselected package libdrm-intel1:amd64.
# Preparing to unpack .../09-libdrm-intel1_2.4.104-1_amd64.deb ...
# Unpacking libdrm-intel1:amd64 (2.4.104-1) ...
# Selecting previously unselected package libdrm-nouveau2:amd64.
# Preparing to unpack .../10-libdrm-nouveau2_2.4.104-1_amd64.deb ...
# 7Progress: [  8%] [####......................................................] 8Unpacking libdrm-nouveau2:amd64 (2.4.104-1) ...
# Selecting previously unselected package libdrm-radeon1:amd64.
# Preparing to unpack .../11-libdrm-radeon1_2.4.104-1_amd64.deb ...
# Unpacking libdrm-radeon1:amd64 (2.4.104-1) ...
# 7Progress: [  9%] [#####.....................................................] 8Selecting previously unselected package libelf1:amd64.
# Preparing to unpack .../12-libelf1_0.183-1_amd64.deb ...
# Unpacking libelf1:amd64 (0.183-1) ...
# 7Progress: [ 10%] [#####.....................................................] 8Selecting previously unselected package libfontenc1:amd64.
# Preparing to unpack .../13-libfontenc1_1%3a1.1.4-1_amd64.deb ...
# Unpacking libfontenc1:amd64 (1:1.1.4-1) ...
# Selecting previously unselected package libglapi-mesa:amd64.
# Preparing to unpack .../14-libglapi-mesa_20.3.5-1_amd64.deb ...
# 7Progress: [ 11%] [######....................................................] 8Unpacking libglapi-mesa:amd64 (20.3.5-1) ...
# Selecting previously unselected package libz3-4:amd64.
# Preparing to unpack .../15-libz3-4_4.8.10-1_amd64.deb ...
# 7Progress: [ 12%] [######....................................................] 8Unpacking libz3-4:amd64 (4.8.10-1) ...
# Selecting previously unselected package libllvm11:amd64.
# Preparing to unpack .../16-libllvm11_1%3a11.0.1-2_amd64.deb ...
# Unpacking libllvm11:amd64 (1:11.0.1-2) ...
# 7Progress: [ 13%] [#######...................................................] 8Selecting previously unselected package libsensors-config.
# Preparing to unpack .../17-libsensors-config_1%3a3.6.0-7_all.deb ...
# Unpacking libsensors-config (1:3.6.0-7) ...
# 7Progress: [ 14%] [########..................................................] 8Selecting previously unselected package libsensors5:amd64.
# Preparing to unpack .../18-libsensors5_1%3a3.6.0-7_amd64.deb ...
# Unpacking libsensors5:amd64 (1:3.6.0-7) ...
# Selecting previously unselected package libvulkan1:amd64.
# Preparing to unpack .../19-libvulkan1_1.2.162.0-1_amd64.deb ...
# 7Progress: [ 15%] [########..................................................] 8Unpacking libvulkan1:amd64 (1.2.162.0-1) ...
# Selecting previously unselected package libgl1-mesa-dri:amd64.
# Preparing to unpack .../20-libgl1-mesa-dri_20.3.5-1_amd64.deb ...
# Unpacking libgl1-mesa-dri:amd64 (20.3.5-1) ...
# 7Progress: [ 16%] [#########.................................................] 8Selecting previously unselected package libglvnd0:amd64.
# Preparing to unpack .../21-libglvnd0_1.3.2-1_amd64.deb ...
# Unpacking libglvnd0:amd64 (1.3.2-1) ...
# 7Progress: [ 17%] [#########.................................................] 8Selecting previously unselected package libx11-xcb1:amd64.
# Preparing to unpack .../22-libx11-xcb1_2%3a1.7.2-1+deb11u2_amd64.deb ...
# Unpacking libx11-xcb1:amd64 (2:1.7.2-1+deb11u2) ...
# Selecting previously unselected package libxcb-dri2-0:amd64.
# Preparing to unpack .../23-libxcb-dri2-0_1.14-3_amd64.deb ...
# 7Progress: [ 18%] [##########................................................] 8Unpacking libxcb-dri2-0:amd64 (1.14-3) ...
# Selecting previously unselected package libxcb-dri3-0:amd64.
# Preparing to unpack .../24-libxcb-dri3-0_1.14-3_amd64.deb ...
# 7Progress: [ 19%] [###########...............................................] 8Unpacking libxcb-dri3-0:amd64 (1.14-3) ...
# Selecting previously unselected package libxcb-glx0:amd64.
# Preparing to unpack .../25-libxcb-glx0_1.14-3_amd64.deb ...
# Unpacking libxcb-glx0:amd64 (1.14-3) ...
# 7Progress: [ 20%] [###########...............................................] 8Selecting previously unselected package libxcb-present0:amd64.
# Preparing to unpack .../26-libxcb-present0_1.14-3_amd64.deb ...
# Unpacking libxcb-present0:amd64 (1.14-3) ...
# 7Progress: [ 21%] [############..............................................] 8Selecting previously unselected package libxcb-shm0:amd64.
# Preparing to unpack .../27-libxcb-shm0_1.14-3_amd64.deb ...
# Unpacking libxcb-shm0:amd64 (1.14-3) ...
# Selecting previously unselected package libxcb-sync1:amd64.
# Preparing to unpack .../28-libxcb-sync1_1.14-3_amd64.deb ...
# 7Progress: [ 22%] [############..............................................] 8Unpacking libxcb-sync1:amd64 (1.14-3) ...
# Selecting previously unselected package libxcb-xfixes0:amd64.
# Preparing to unpack .../29-libxcb-xfixes0_1.14-3_amd64.deb ...
# Unpacking libxcb-xfixes0:amd64 (1.14-3) ...
# 7Progress: [ 23%] [#############.............................................] 8Selecting previously unselected package libxdamage1:amd64.
# Preparing to unpack .../30-libxdamage1_1%3a1.1.5-2_amd64.deb ...
# Unpacking libxdamage1:amd64 (1:1.1.5-2) ...
# 7Progress: [ 24%] [#############.............................................] 8Selecting previously unselected package libxext6:amd64.
# Preparing to unpack .../31-libxext6_2%3a1.3.3-1.1_amd64.deb ...
# Unpacking libxext6:amd64 (2:1.3.3-1.1) ...
# Selecting previously unselected package libxfixes3:amd64.
# Preparing to unpack .../32-libxfixes3_1%3a5.0.3-2_amd64.deb ...
# 7Progress: [ 25%] [##############............................................] 8Unpacking libxfixes3:amd64 (1:5.0.3-2) ...
# Selecting previously unselected package libxshmfence1:amd64.
# Preparing to unpack .../33-libxshmfence1_1.3-1_amd64.deb ...
# 7Progress: [ 26%] [###############...........................................] 8Unpacking libxshmfence1:amd64 (1.3-1) ...
# Selecting previously unselected package libxxf86vm1:amd64.
# Preparing to unpack .../34-libxxf86vm1_1%3a1.1.4-1+b2_amd64.deb ...
# Unpacking libxxf86vm1:amd64 (1:1.1.4-1+b2) ...
# 7Progress: [ 27%] [###############...........................................] 8Selecting previously unselected package libglx-mesa0:amd64.
# Preparing to unpack .../35-libglx-mesa0_20.3.5-1_amd64.deb ...
# Unpacking libglx-mesa0:amd64 (20.3.5-1) ...
# 7Progress: [ 28%] [################..........................................] 8Selecting previously unselected package x11-common.
# Preparing to unpack .../36-x11-common_1%3a7.7+22_all.deb ...
# Unpacking x11-common (1:7.7+22) ...
# Selecting previously unselected package libice6:amd64.
# Preparing to unpack .../37-libice6_2%3a1.0.10-1_amd64.deb ...
# 7Progress: [ 29%] [################..........................................] 8Unpacking libice6:amd64 (2:1.0.10-1) ...
# Selecting previously unselected package libsm6:amd64.
# Preparing to unpack .../38-libsm6_2%3a1.2.3-1_amd64.deb ...
# Unpacking libsm6:amd64 (2:1.2.3-1) ...
# 7Progress: [ 30%] [#################.........................................] 8Selecting previously unselected package libwayland-client0:amd64.
# Preparing to unpack .../39-libwayland-client0_1.18.0-2~exp1.1_amd64.deb ...
# Unpacking libwayland-client0:amd64 (1.18.0-2~exp1.1) ...
# 7Progress: [ 31%] [##################........................................] 8Selecting previously unselected package libxt6:amd64.
# Preparing to unpack .../40-libxt6_1%3a1.2.0-1_amd64.deb ...
# Unpacking libxt6:amd64 (1:1.2.0-1) ...
# Selecting previously unselected package libxmu6:amd64.
# Preparing to unpack .../41-libxmu6_2%3a1.1.2-2+b3_amd64.deb ...
# 7Progress: [ 32%] [##################........................................] 8Unpacking libxmu6:amd64 (2:1.1.2-2+b3) ...
# Selecting previously unselected package libxaw7:amd64.
# Preparing to unpack .../42-libxaw7_2%3a1.0.13-1.1_amd64.deb ...
# 7Progress: [ 33%] [###################.......................................] 8Unpacking libxaw7:amd64 (2:1.0.13-1.1) ...
# Selecting previously unselected package libxcb-randr0:amd64.
# Preparing to unpack .../43-libxcb-randr0_1.14-3_amd64.deb ...
# Unpacking libxcb-randr0:amd64 (1.14-3) ...
# 7Progress: [ 34%] [###################.......................................] 8Selecting previously unselected package libxcb-shape0:amd64.
# Preparing to unpack .../44-libxcb-shape0_1.14-3_amd64.deb ...
# Unpacking libxcb-shape0:amd64 (1.14-3) ...
# 7Progress: [ 35%] [####################......................................] 8Selecting previously unselected package libxcomposite1:amd64.
# Preparing to unpack .../45-libxcomposite1_1%3a0.4.5-1_amd64.deb ...
# Unpacking libxcomposite1:amd64 (1:0.4.5-1) ...
# Selecting previously unselected package libxrender1:amd64.
# Preparing to unpack .../46-libxrender1_1%3a0.9.10-1_amd64.deb ...
# 7Progress: [ 36%] [####################......................................] 8Unpacking libxrender1:amd64 (1:0.9.10-1) ...
# Selecting previously unselected package libxcursor1:amd64.
# Preparing to unpack .../47-libxcursor1_1%3a1.2.0-2_amd64.deb ...
# Unpacking libxcursor1:amd64 (1:1.2.0-2) ...
# 7Progress: [ 37%] [#####################.....................................] 8Selecting previously unselected package libxft2:amd64.
# Preparing to unpack .../48-libxft2_2.3.2-2_amd64.deb ...
# Unpacking libxft2:amd64 (2.3.2-2) ...
# 7Progress: [ 38%] [######################....................................] 8Selecting previously unselected package libxi6:amd64.
# Preparing to unpack .../49-libxi6_2%3a1.7.10-1_amd64.deb ...
# Unpacking libxi6:amd64 (2:1.7.10-1) ...
# Selecting previously unselected package libxinerama1:amd64.
# Preparing to unpack .../50-libxinerama1_2%3a1.1.4-2_amd64.deb ...
# 7Progress: [ 39%] [######################....................................] 8Unpacking libxinerama1:amd64 (2:1.1.4-2) ...
# Selecting previously unselected package libxkbfile1:amd64.
# Preparing to unpack .../51-libxkbfile1_1%3a1.1.0-1_amd64.deb ...
# 7Progress: [ 40%] [#######################...................................] 8Unpacking libxkbfile1:amd64 (1:1.1.0-1) ...
# Selecting previously unselected package libxmuu1:amd64.
# Preparing to unpack .../52-libxmuu1_2%3a1.1.2-2+b3_amd64.deb ...
# Unpacking libxmuu1:amd64 (2:1.1.2-2+b3) ...
# 7Progress: [ 41%] [#######################...................................] 8Selecting previously unselected package libxrandr2:amd64.
# Preparing to unpack .../53-libxrandr2_2%3a1.5.1-1_amd64.deb ...
# Unpacking libxrandr2:amd64 (2:1.5.1-1) ...
# 7Progress: [ 42%] [########################..................................] 8Selecting previously unselected package libxtst6:amd64.
# Preparing to unpack .../54-libxtst6_2%3a1.2.3-1_amd64.deb ...
# Unpacking libxtst6:amd64 (2:1.2.3-1) ...
# Selecting previously unselected package libxv1:amd64.
# Preparing to unpack .../55-libxv1_2%3a1.0.11-1_amd64.deb ...
# 7Progress: [ 43%] [#########################.................................] 8Unpacking libxv1:amd64 (2:1.0.11-1) ...
# Selecting previously unselected package libxxf86dga1:amd64.
# Preparing to unpack .../56-libxxf86dga1_2%3a1.1.4-1+b3_amd64.deb ...
# Unpacking libxxf86dga1:amd64 (2:1.1.4-1+b3) ...
# 7Progress: [ 44%] [#########################.................................] 8Selecting previously unselected package mesa-vulkan-drivers:amd64.
# Preparing to unpack .../57-mesa-vulkan-drivers_20.3.5-1_amd64.deb ...
# Unpacking mesa-vulkan-drivers:amd64 (20.3.5-1) ...
# 7Progress: [ 45%] [##########################................................] 8Selecting previously unselected package x11-apps.
# Preparing to unpack .../58-x11-apps_7.7+8_amd64.deb ...
# Unpacking x11-apps (7.7+8) ...
# Selecting previously unselected package libglx0:amd64.
# Preparing to unpack .../59-libglx0_1.3.2-1_amd64.deb ...
# 7Progress: [ 46%] [##########################................................] 8Unpacking libglx0:amd64 (1.3.2-1) ...
# Selecting previously unselected package libgl1:amd64.
# Preparing to unpack .../60-libgl1_1.3.2-1_amd64.deb ...
# 7Progress: [ 47%] [###########################...............................] 8Unpacking libgl1:amd64 (1.3.2-1) ...
# Selecting previously unselected package x11-utils.
# Preparing to unpack .../61-x11-utils_7.7+5_amd64.deb ...
# Unpacking x11-utils (7.7+5) ...
# 7Progress: [ 48%] [###########################...............................] 8Selecting previously unselected package x11-xserver-utils.
# Preparing to unpack .../62-x11-xserver-utils_7.7+8_amd64.deb ...
# Unpacking x11-xserver-utils (7.7+8) ...
# 7Progress: [ 49%] [############################..............................] 8Selecting previously unselected package xbitmaps.
# Preparing to unpack .../63-xbitmaps_1.1.1-2.1_all.deb ...
# Unpacking xbitmaps (1.1.1-2.1) ...
# Setting up libpipeline1:amd64 (1.5.3-1) ...
# 7Progress: [ 50%] [#############################.............................] 8Setting up libxcb-dri3-0:amd64 (1.14-3) ...
# 7Progress: [ 51%] [#############################.............................] 8Setting up libx11-xcb1:amd64 (2:1.7.2-1+deb11u2) ...
# 7Progress: [ 52%] [##############################............................] 8Setting up libpciaccess0:amd64 (0.16-1) ...
# Setting up libxdamage1:amd64 (1:1.1.5-2) ...
# 7Progress: [ 53%] [##############################............................] 8Setting up libxcb-xfixes0:amd64 (1.14-3) ...
# 7Progress: [ 54%] [###############################...........................] 8Setting up bsdextrautils (2.36.1-8+deb11u2) ...
# update-alternatives: using /usr/bin/write.ul to provide /usr/bin/write (write) in auto mode
# 7Progress: [ 55%] [################################..........................] 8Setting up libxrender1:amd64 (1:0.9.10-1) ...
# 7Progress: [ 56%] [################################..........................] 8Setting up libglvnd0:amd64 (1.3.2-1) ...
# Setting up libxcb-glx0:amd64 (1.14-3) ...
# 7Progress: [ 57%] [#################################.........................] 8Setting up libxcb-shape0:amd64 (1.14-3) ...
# 7Progress: [ 58%] [#################################.........................] 8Setting up x11-common (1:7.7+22) ...
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 78.)
# debconf: falling back to frontend: Readline
# invoke-rc.d: could not determine current runlevel
# invoke-rc.d: policy-rc.d denied execution of start.
# 7Progress: [ 59%] [##################################........................] 8Setting up libsensors-config (1:3.6.0-7) ...
# Setting up libxext6:amd64 (2:1.3.3-1.1) ...
# 7Progress: [ 60%] [##################################........................] 8Setting up libxcb-shm0:amd64 (1.14-3) ...
# 7Progress: [ 61%] [###################################.......................] 8Setting up libxxf86vm1:amd64 (1:1.1.4-1+b2) ...
# 7Progress: [ 62%] [####################################......................] 8Setting up libxcb-present0:amd64 (1.14-3) ...
# 7Progress: [ 63%] [####################################......................] 8Setting up libfontenc1:amd64 (1:1.1.4-1) ...
# Setting up libz3-4:amd64 (4.8.10-1) ...
# 7Progress: [ 64%] [#####################################.....................] 8Setting up libllvm11:amd64 (1:11.0.1-2) ...
# 7Progress: [ 65%] [#####################################.....................] 8Setting up libxfixes3:amd64 (1:5.0.3-2) ...
# 7Progress: [ 66%] [######################################....................] 8Setting up libxcb-sync1:amd64 (1.14-3) ...
# Setting up libxinerama1:amd64 (2:1.1.4-2) ...
# 7Progress: [ 67%] [#######################################...................] 8Setting up libxv1:amd64 (2:1.0.11-1) ...
# 7Progress: [ 68%] [#######################################...................] 8Setting up libxrandr2:amd64 (2:1.5.1-1) ...
# 7Progress: [ 69%] [########################################..................] 8Setting up libsensors5:amd64 (1:3.6.0-7) ...
# 7Progress: [ 70%] [########################################..................] 8Setting up libglapi-mesa:amd64 (20.3.5-1) ...
# Setting up libvulkan1:amd64 (1.2.162.0-1) ...
# 7Progress: [ 71%] [#########################################.................] 8Setting up libxcb-dri2-0:amd64 (1.14-3) ...
# 7Progress: [ 72%] [#########################################.................] 8Setting up libxshmfence1:amd64 (1.3-1) ...
# 7Progress: [ 73%] [##########################################................] 8Setting up libxcb-randr0:amd64 (1.14-3) ...
# Setting up libuchardet0:amd64 (0.0.7-1) ...
# 7Progress: [ 74%] [###########################################...............] 8Setting up libxkbfile1:amd64 (1:1.1.0-1) ...
# 7Progress: [ 75%] [###########################################...............] 8Setting up libdrm-common (2.4.104-1) ...
# 7Progress: [ 76%] [############################################..............] 8Setting up libelf1:amd64 (0.183-1) ...
# 7Progress: [ 77%] [############################################..............] 8Setting up libxcomposite1:amd64 (1:0.4.5-1) ...
# Setting up libxmuu1:amd64 (2:1.1.2-2+b3) ...
# 7Progress: [ 78%] [#############################################.............] 8Setting up xbitmaps (1.1.1-2.1) ...
# 7Progress: [ 79%] [##############################################............] 8Setting up libwayland-client0:amd64 (1.18.0-2~exp1.1) ...
# 7Progress: [ 80%] [##############################################............] 8Setting up libice6:amd64 (2:1.0.10-1) ...
# Setting up libxft2:amd64 (2.3.2-2) ...
# 7Progress: [ 81%] [###############################################...........] 8Setting up libxi6:amd64 (2:1.7.10-1) ...
# 7Progress: [ 82%] [###############################################...........] 8Setting up libxtst6:amd64 (2:1.2.3-1) ...
# 7Progress: [ 83%] [################################################..........] 8Setting up libxcursor1:amd64 (1:1.2.0-2) ...
# 7Progress: [ 84%] [################################################..........] 8Setting up libxxf86dga1:amd64 (2:1.1.4-1+b3) ...
# Setting up libdrm2:amd64 (2.4.104-1) ...
# 7Progress: [ 85%] [#################################################.........] 8Setting up groff-base (1.22.4-6) ...
# 7Progress: [ 86%] [##################################################........] 8Setting up libsm6:amd64 (2:1.2.3-1) ...
# 7Progress: [ 87%] [##################################################........] 8Setting up libdrm-amdgpu1:amd64 (2.4.104-1) ...
# Setting up mesa-vulkan-drivers:amd64 (20.3.5-1) ...
# 7Progress: [ 88%] [###################################################.......] 8Setting up libdrm-nouveau2:amd64 (2.4.104-1) ...
# 7Progress: [ 89%] [###################################################.......] 8Setting up libdrm-radeon1:amd64 (2.4.104-1) ...
# 7Progress: [ 90%] [####################################################......] 8Setting up libdrm-intel1:amd64 (2.4.104-1) ...
# 7Progress: [ 91%] [####################################################......] 8Setting up libgl1-mesa-dri:amd64 (20.3.5-1) ...
# Setting up man-db (2.9.4-2) ...
# 7Progress: [ 92%] [#####################################################.....] 8debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 78.)
# debconf: falling back to frontend: Readline
# Building database of manual pages ...
# Setting up libxt6:amd64 (1:1.2.0-1) ...
# 7Progress: [ 93%] [######################################################....] 8Setting up libxmu6:amd64 (2:1.1.2-2+b3) ...
# 7Progress: [ 94%] [######################################################....] 8Setting up libglx-mesa0:amd64 (20.3.5-1) ...
# Setting up libglx0:amd64 (1.3.2-1) ...
# 7Progress: [ 95%] [#######################################################...] 8Setting up libxaw7:amd64 (2:1.0.13-1.1) ...
# 7Progress: [ 96%] [#######################################################...] 8Setting up x11-xserver-utils (7.7+8) ...
# 7Progress: [ 97%] [########################################################..] 8Setting up libgl1:amd64 (1.3.2-1) ...
# 7Progress: [ 98%] [########################################################..] 8Setting up x11-utils (7.7+5) ...
# Setting up x11-apps (7.7+8) ...
# 7Progress: [ 99%] [#########################################################.] 8Processing triggers for libc-bin (2.31-13+deb11u3) ...
#
# 78

# %% [markdown]
# ### 12.1 Nakamura juega con blancas
# Incluye el giro de tablero y reestructuración de la notación. Para jugar hacer clic en pieza que se quiere mover y clic en la casilla destino de la pieza.

# %%
import pygame
import chess
import numpy as np
from tensorflow.keras.models import load_model
from stockfish import Stockfish
import os

# --- CONFIGURACIÓN ---
MODEL_PATH = "/notebooks/datos_cnn/modelo_blancas"
STOCKFISH_PATH = "motor_ejecutable/stockfish"
ENCODER_PATH = "encoder_blancas.npy"  # Guardado tras el entrenamiento

# Inicializar pygame
pygame.init()
WIDTH, HEIGHT = 800, 800
SQ_SIZE = WIDTH // 8
screen = pygame.display.set_mode((WIDTH, HEIGHT))
pygame.display.set_caption("Juega contra Nakamura")

# Cargar imágenes con rutas absolutas
BASE_DIR = os.getcwd()
PIECE_DIR = os.path.join(BASE_DIR, "pieces")

PIECE_IMAGES = {}
PIECE_MAPPING = {
    "r": "R1", "n": "N1", "b": "B1", "q": "Q1", "k": "K1", "p": "P1",
    "R": "R", "N": "N", "B": "B", "Q": "Q", "K": "K", "P": "P"
}
for symbol, name in PIECE_MAPPING.items():
    PIECE_IMAGES[symbol] = pygame.transform.scale(
        pygame.image.load(f"pieces/{name}.png"), (SQ_SIZE, SQ_SIZE))

# Cargar modelo y encoder
model = load_model(MODEL_PATH)
encoder_classes = np.load(ENCODER_PATH, allow_pickle=True)

# Iniciar motor
stockfish = Stockfish(path=STOCKFISH_PATH, parameters={"Threads": 2, "Minimum Thinking Time": 100})
stockfish.set_elo_rating(2800)
stockfish.set_skill_level(20)

def fen_to_tensor(fen):
    piece_to_plane = {
        'P': 0, 'N': 1, 'B': 2, 'R': 3, 'Q': 4, 'K': 5,
        'p': 6, 'n': 7, 'b': 8, 'r': 9, 'q': 10, 'k': 11
    }
    tensor = np.zeros((8, 8, 12), dtype=np.float32)
    fen_board = fen.split(' ')[0]
    rows = fen_board.split('/')
    for i, row in enumerate(rows):
        col = 0
        for char in row:
            if char.isdigit():
                col += int(char)
            elif char in piece_to_plane:
                tensor[i, col, piece_to_plane[char]] = 1
                col += 1
    return tensor

def flip_square_name(uci_move):
    col_map = {'a': 'h', 'b': 'g', 'c': 'f', 'd': 'e', 'e': 'd', 'f': 'c', 'g': 'b', 'h': 'a'}
    def flip(sq):
        col, row = sq[0], sq[1]
        return col_map[col] + str(9 - int(row))
    return flip(uci_move[:2]) + flip(uci_move[2:4])

def predict_move(fen, board, top_n=10, umbral_cp=20):
    stockfish.set_fen_position(fen)
    eval_info = stockfish.get_evaluation()
    
    if eval_info["type"] == "mate" and eval_info["value"] is not None and eval_info["value"] <= 3:
        best_uci = stockfish.get_best_move()
        print("¡Mate detectado! Stockfish lo ejecuta:", best_uci)
        return chess.Move.from_uci(best_uci)

    top_moves_info = stockfish.get_top_moves(top_n)
    if not top_moves_info:
        print("No hay jugadas válidas.")
        return np.random.choice(list(board.legal_moves))

    best_eval = top_moves_info[0].get("Centipawn")
    if best_eval is None:
        print("Evaluación no disponible. Stockfish mueve.")
        return chess.Move.from_uci(top_moves_info[0]["Move"])

    candidatas = [m for m in top_moves_info if abs(best_eval - m.get("Centipawn", 0)) <= umbral_cp]

    if len(candidatas) == 1:
        best_move = chess.Move.from_uci(candidatas[0]["Move"])
        print("Jugada clara. Stockfish la ejecuta:", best_move.uci())
        return best_move

    tensor = fen_to_tensor(fen).reshape(1, 8, 8, 12)
    prediction = model.predict(tensor, verbose=0)[0]

    scored = []
    for move_info in candidatas:
        move_uci = move_info["Move"]
        try:
            idx = np.where(encoder_classes == move_uci)[0][0]
            ia_score = prediction[idx]
        except IndexError:
            ia_score = 0.0
        scored.append((move_uci, ia_score))

    best_uci, best_score = max(scored, key=lambda x: x[1])
    print(f"Jugada estilo Nakamura: {flip_square_name(best_uci)} (IA score: {best_score:.4f})")
    return chess.Move.from_uci(best_uci)

def draw_board(board):
    colors = [pygame.Color("white"), pygame.Color("gray")]
    for row in range(8):
        for col in range(8):
            color = colors[(row + col) % 2]
            pygame.draw.rect(screen, color, pygame.Rect(col * SQ_SIZE, row * SQ_SIZE, SQ_SIZE, SQ_SIZE))

    for row in range(8):
        for col in range(8):
            visual_row = row
            visual_col = col
            square = chess.square(7 - visual_col, visual_row)
            piece = board.piece_at(square)
            if piece:
                img = PIECE_IMAGES.get(piece.symbol())
                if img:
                    screen.blit(img, (col * SQ_SIZE, row * SQ_SIZE))

# Bucle principal
board = chess.Board()
running = True
selected_square = None
game_over = False

draw_board(board)
pygame.display.flip()

# Movimiento de apertura del bot
ai_move = predict_move(board.fen(), board)
board.push(ai_move)

while running:
    draw_board(board)
    pygame.display.flip()

    if not game_over and board.is_game_over():
        game_over = True
        result = board.result()
        if board.is_checkmate():
            winner = "Blancas" if board.turn == chess.BLACK else "Negras"
            print(f"Jaque mate. Ganan {winner}")
        else:
            print("Tablas")

    for event in pygame.event.get():
        if event.type == pygame.QUIT:
            running = False

        elif event.type == pygame.MOUSEBUTTONDOWN and not game_over:
            x, y = pygame.mouse.get_pos()
            col = 7 - (x // SQ_SIZE)
            row = y // SQ_SIZE
            square = chess.square(col, row)

            if selected_square is None:
                piece = board.piece_at(square)
                if piece and piece.color == chess.BLACK:
                    selected_square = square
            else:
                move = chess.Move(selected_square, square)
                if move in board.legal_moves:
                    board.push(move)
                    if not board.is_game_over():
                        ai_move = predict_move(board.fen(), board)
                        board.push(ai_move)
                selected_square = None

pygame.quit()
# Out:
# libGL error: MESA-LOADER: failed to retrieve device information
# MESA-LOADER: failed to retrieve device information
# MESA-LOADER: failed to retrieve device information
# Jugada estilo Nakamura: d7d5 (IA score: 0.3141)

# %% [markdown]
# ### 12.1 Nakamura juega con negras

# %%
import pygame
import chess
import numpy as np
from tensorflow.keras.models import load_model
from stockfish import Stockfish
import os

# --- CONFIGURACIÓN ---
MODEL_PATH = "/notebooks/datos_cnn/modelo_negras"
STOCKFISH_PATH = "motor_ejecutable/stockfish"
ENCODER_PATH = "encoder_negras.npy"

# Inicializar pygame
pygame.init()
WIDTH, HEIGHT = 800, 800
SQ_SIZE = WIDTH // 8
screen = pygame.display.set_mode((WIDTH, HEIGHT))
pygame.display.set_caption("Juega contra Nakamura (negras)")

# Cargar imágenes
BASE_DIR = os.getcwd()
PIECE_DIR = os.path.join(BASE_DIR, "pieces")

PIECE_IMAGES = {}
PIECE_MAPPING = {
    "r": "R1", "n": "N1", "b": "B1", "q": "Q1", "k": "K1", "p": "P1",
    "R": "R", "N": "N", "B": "B", "Q": "Q", "K": "K", "P": "P"
}
for symbol, name in PIECE_MAPPING.items():
    PIECE_IMAGES[symbol] = pygame.transform.scale(
        pygame.image.load(os.path.join(PIECE_DIR, f"{name}.png")), (SQ_SIZE, SQ_SIZE))

# Cargar modelo y encoder
model = load_model(MODEL_PATH)
encoder_classes = np.load(ENCODER_PATH, allow_pickle=True)

# Iniciar motor
stockfish = Stockfish(path=STOCKFISH_PATH, parameters={"Threads": 2, "Minimum Thinking Time": 100})
stockfish.set_elo_rating(2800)
stockfish.set_skill_level(20)

def fen_to_tensor(fen):
    piece_to_plane = {
        'P': 0, 'N': 1, 'B': 2, 'R': 3, 'Q': 4, 'K': 5,
        'p': 6, 'n': 7, 'b': 8, 'r': 9, 'q': 10, 'k': 11
    }
    tensor = np.zeros((8, 8, 12), dtype=np.float32)
    fen_board = fen.split(' ')[0]
    rows = fen_board.split('/')
    for i, row in enumerate(rows):
        col = 0
        for char in row:
            if char.isdigit():
                col += int(char)
            elif char in piece_to_plane:
                tensor[i, col, piece_to_plane[char]] = 1
                col += 1
    return tensor

def flip_square_name(uci_move):
    col_map = {'a': 'h', 'b': 'g', 'c': 'f', 'd': 'e', 'e': 'd', 'f': 'c', 'g': 'b', 'h': 'a'}
    def flip(sq):
        col, row = sq[0], sq[1]
        return col_map[col] + str(9 - int(row))
    return flip(uci_move[:2]) + flip(uci_move[2:4])

def predict_move(fen, board, top_n=10, umbral_cp=20):
    stockfish.set_fen_position(fen)
    eval_info = stockfish.get_evaluation()

    if eval_info["type"] == "mate" and eval_info["value"] is not None and eval_info["value"] <= 3:
        best_uci = stockfish.get_best_move()
        print("¡Mate detectado! Stockfish lo ejecuta:", best_uci)
        return chess.Move.from_uci(best_uci)

    top_moves_info = stockfish.get_top_moves(top_n)
    if not top_moves_info:
        print("No hay jugadas válidas.")
        return np.random.choice(list(board.legal_moves))

    best_eval = top_moves_info[0].get("Centipawn")
    if best_eval is None:
        print("Evaluación no disponible. Stockfish mueve.")
        return chess.Move.from_uci(top_moves_info[0]["Move"])

    candidatas = [m for m in top_moves_info if abs(best_eval - m.get("Centipawn", 0)) <= umbral_cp]

    if len(candidatas) == 1:
        best_move = chess.Move.from_uci(candidatas[0]["Move"])
        print("Jugada clara. Stockfish la ejecuta:", best_move.uci())
        return best_move

    tensor = fen_to_tensor(fen).reshape(1, 8, 8, 12)
    prediction = model.predict(tensor, verbose=0)[0]

    scored = []
    for move_info in candidatas:
        move_uci = move_info["Move"]
        try:
            idx = np.where(encoder_classes == move_uci)[0][0]
            ia_score = prediction[idx]
        except IndexError:
            ia_score = 0.0
        scored.append((move_uci, ia_score))

    best_uci, best_score = max(scored, key=lambda x: x[1])
    print(f"Jugada estilo Nakamura: {flip_square_name(best_uci)} (IA score: {best_score:.4f})")
    return chess.Move.from_uci(best_uci)

def draw_board(board):
    colors = [pygame.Color("white"), pygame.Color("gray")]
    for row in range(8):
        for col in range(8):
            color = colors[(row + col) % 2]
            pygame.draw.rect(screen, color, pygame.Rect(col * SQ_SIZE, row * SQ_SIZE, SQ_SIZE, SQ_SIZE))

    for row in range(8):
        for col in range(8):
            square = chess.square(col, 7 - row)  # Blancas abajo
            piece = board.piece_at(square)
            if piece:
                img = PIECE_IMAGES.get(piece.symbol())
                if img:
                    screen.blit(img, (col * SQ_SIZE, row * SQ_SIZE))

# Bucle principal
board = chess.Board()
running = True
selected_square = None
game_over = False

draw_board(board)
pygame.display.flip()

# Esperar jugada del humano (blancas)

while running:
    draw_board(board)
    pygame.display.flip()

    if not game_over and board.is_game_over():
        game_over = True
        result = board.result()
        if board.is_checkmate():
            winner = "Blancas" if board.turn == chess.BLACK else "Negras"
            print(f"Jaque mate. Ganan {winner}")
        else:
            print("Tablas")

    for event in pygame.event.get():
        if event.type == pygame.QUIT:
            running = False

        elif event.type == pygame.MOUSEBUTTONDOWN and not game_over:
            x, y = pygame.mouse.get_pos()
            col = x // SQ_SIZE
            row = 7 - (y // SQ_SIZE)
            square = chess.square(col, row)

            if selected_square is None:
                piece = board.piece_at(square)
                if piece and piece.color == chess.WHITE:
                    selected_square = square
            else:
                move = chess.Move(selected_square, square)
                if move in board.legal_moves:
                    board.push(move)
                    if not board.is_game_over():
                        ai_move = predict_move(board.fen(), board)
                        board.push(ai_move)
                selected_square = None

pygame.quit()
# Out:
# WARNING:tensorflow:5 out of the last 14 calls to <function Model.make_predict_function.<locals>.predict_function at 0x71accb9b7dc0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Jugada estilo Nakamura: f2f3 (IA score: 0.1203)
# Jugada clara. Stockfish la ejecuta: d7d5
